# %%
import pandas as pd

# %%
data = pd.read_csv("../data/house_rent_train.csv")

# %%
data
# Out:
#        posted_on  bhk   rent  size            floor    area_type
# 0     2022-04-23    2   7000   450       1 out of 3  Carpet Area  \
# 1     2022-04-23    1   6500   800  Ground out of 1  Carpet Area
# 2     2022-04-23    2  20000   700       1 out of 2   Super Area
# 3     2022-04-23    3  36125  1700  Ground out of 2   Super Area
# 4     2022-04-23    2   8000   650       1 out of 2   Super Area
# ...          ...  ...    ...   ...              ...          ...
# 2688  2022-06-15    2  13000   650  Ground out of 4  Carpet Area
# 2689  2022-06-15    2  11000   700  Ground out of 2  Carpet Area
# 2690  2022-06-15    3  16000  1305       2 out of 5   Super Area
# 2691  2022-06-15    1   6000   300       1 out of 2  Carpet Area
# 2692  2022-06-15    3  20000  1100  Ground out of 1  Carpet Area
#
#                   area_locality       city furnishing_status
# 0                     safuipara    Kolkata         Furnished  \
# ...

# %%
data.floor.unique()
# Out:
# array(['1 out of 3', 'Ground out of 1', '1 out of 2', 'Ground out of 2',
#        '2 out of 3', 'Ground out of 3', '2 out of 4', '1 out of 1',
#        '3 out of 4', '2 out of 5', '2 out of 2', '1 out of 5',
#        '3 out of 3', '5 out of 20', 'Ground out of 4', '10 out of 22',
#        '15 out of 15', '2 out of 7', '8 out of 10', '6 out of 7',
#        '3 out of 8', '3 out of 7', '1 out of 4', '4 out of 7',
#        '1 out of 24', 'Upper Basement out of 3', '3 out of 5',
#        '4 out of 5', '12 out of 17', '1 out of 7', '6 out of 10',
#        '4 out of 15', '13 out of 16', '7 out of 8', '5 out of 9',
#        '2 out of 8', '12 out of 13', '18 out of 19', '4 out of 4',
#        'Upper Basement out of 7', '11 out of 23', '3 out of 6',
#        '1 out of 8', '4 out of 8', '21 out of 22', 'Ground out of 5',
#        '4 out of 10', '4 out of 6', 'Lower Basement out of 3',
#        '15 out of 20', '5 out of 7', '4 out of 14', '7 out of 14',
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2693 entries, 0 to 2692
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   posted_on          2693 non-null   object
#  1   bhk                2693 non-null   int64
#  2   rent               2693 non-null   int64
#  3   size               2693 non-null   int64
#  4   floor              2693 non-null   object
#  5   area_type          2693 non-null   object
#  6   area_locality      2693 non-null   object
#  7   city               2693 non-null   object
#  8   furnishing_status  2693 non-null   object
#  9   tenant_preferred   2693 non-null   object
#  10  bathroom           2693 non-null   int64
#  11  point_of_contact   2693 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 252.6+ KB
